# %%
import pandas as pd

# %%
df_protocol = pd.read_csv('CT_protocol_data.csv')

# %%
df_protocol.columns
# Out:
# Index(['scan_protocol_no', 'scan_protocol_name', 'scan_series', 'Speed',
#        'Type', 'Rows', 'HiRes', 'Shuttle', 'Tilt', 'SFOV', 'kV', 'SmartmA',
#        'NoiseIndex', 'MinmA', 'MaxmA', 'Message', 'Timer', 'Light', 'CTDI',
#        'CTDI NV', 'DLP', 'DLP NV', 'mA', ' pitch'],
#       dtype='object')

# %%
drop_columns = ['Type', 'HiRes', 'Shuttle', 'Tilt', 'Message', 'Timer', 'Light', 'CTDI NV', 'DLP', 'DLP NV',]

# %%
df_protocol['scan_protocol'] = df_protocol.apply(lambda row: row['scan_protocol_no'] + row['scan_protocol_name'], axis=1)

# %%
df_protocol
# Out:
#     scan_protocol_no                      scan_protocol_name  \
# 0                1.5             QQ Brain-Head Routine TFI-H
# 1                1.3                      Dental non-Helical
# 2                1.4            QQ Brain non-Helical Routine
# 3               1.11      Head CTA 1Volume SmartPrep Routine
# 4               1.11      Head CTA 1Volume SmartPrep Routine
# ..               ...                                     ...
# 516             17.1                   Child L-Spine Routine
# 517             18.1                     Child Pelvis Rotine
# 518             18.1                     Child Pelvis Rotine
# 519             19.1   Child Lower Extremity Heiical Routine
# 520             19.2     Child Knee/Ankle Helical HR Routine
#
#                          scan_series  Speed               Rows         SFOV  \
# 0                           Series 1    0.8                 64   Adult Head
# 1                                NaN    1.0   SmartCollimation   Adult Head
# 2                                NaN    1.0                256   Adult Head
# 3    Series 2 Group 1 Scan Settings     1.0   SmartCollimation   Adult Head
# 4    Series 3 Group 1 Scan Settings     1.0   SmartCollimation   Adult Head
# ..                               ...    ...                ...          ...
# 516  Series 2 Group 1 Scan Settings     0.6                128   Small Body
# 517  Series 2 Group 1 Scan Settings     0.6                128   Small Body
# 518  Series 3 Group 1 Scan Settings     0.6                128       Medium
# 519  Series 2 Group 1 Scan Settings     0.6                128   Small Body
# 520  Series 2 Group 1 Scan Settings     0.6                 64       Medium
#
#       kV SmartmA  NoiseIndex  MinmA  MaxmA   CTDI   mA  pitch  \
# 0    100    true         4.0  150.0  515.0  55.19  NaN    NaN
# 1    140    true        18.0   80.0  150.0  29.72  NaN    NaN
# 2    100    true         4.0  200.0  720.0  66.38  NaN    NaN
# 3    100    true         3.2  200.0  720.0  55.26  NaN    NaN
# 4    100    true         3.2  200.0  570.0  52.50  NaN    NaN
# ..   ...     ...         ...    ...    ...    ...  ...    ...
# 516  100    true        11.6  150.0  700.0   8.46  NaN    NaN
# 517  100   false        11.6  150.0  720.0  16.99  NaN    NaN
# 518  100    true        11.6  150.0  720.0  20.04  NaN    NaN
# 519  100    true         4.1  100.0  570.0   8.58  NaN    NaN
# 520  100    true         4.1  100.0  450.0  10.25  NaN    NaN
#
#                                   scan_protocol
# 0               1.5 QQ Brain-Head Routine TFI-H
# 1                        1.3 Dental non-Helical
# 2              1.4 QQ Brain non-Helical Routine
# 3       1.11 Head CTA 1Volume SmartPrep Routine
# 4       1.11 Head CTA 1Volume SmartPrep Routine
# ..                                          ...
# 516                  17.1 Child L-Spine Routine
# 517                    18.1 Child Pelvis Rotine
# 518                    18.1 Child Pelvis Rotine
# 519  19.1 Child Lower Extremity Heiical Routine
# 520    19.2 Child Knee/Ankle Helical HR Routine
#
# [521 rows x 15 columns]

# %%
def preprocess_import_data(df):
    """この関数は、読み込んだデータを整形して、列名を変更する関数です.
    
    params:
        df: 読み込んだDataFrame
        
    Return:
        df: データ整形後のDataFrame
    """
    df.drop('Unnamed: 0', axis=1, inplace=True)
    # 予測に不要な特徴量を削除する
    # 実施検査日、study_date, accessionno, 患者ID, プリセット名称は削除
    drop_list = ['実施検査日(YYYYMMDD)', 'study_date', 'ACCESSIONNO', '患者ID', 'プリセット名称', 'DLP']
    df.drop(drop_list, axis=True, inplace=True)
    
    # column名を変更する
    df.rename(columns={'検査時年齢': 'age', '性別': 'gender', '身長（ｃｍ）': 'height_cm', '体重（ｋｇ）': 'weight_kg',
                       '依頼科名称': 'department', '入院病棟名称': 'hospital_ward', '実施検査室名称': 'room', '撮影機種': 'modality', 
                       '部位名称': 'scan_area', '検査方法': 'scan_method'}, inplace=True)
    # 予測に使う装置
    df.query('modality == "Revolution"', inplace=True)
    
    # 現状ではroom, modalityは１つだけを想定しているので、dropする。
    df.drop(['room', 'modality'], axis=1, inplace=True)

    # hospital_wardのNaNは'外来'を意味する
    df.loc[df['hospital_ward'].isna(), 'hospital_ward'] = '外来'
    
    df.reset_index(inplace=True)
    df.drop(['index', 'kV', 'rotation_time', 'scan_series'], axis=1, inplace=True)

# %%
df = pd.concat([pd.read_excel('../scan_data/202109_all_scan_data.xlsx'), 
                pd.read_excel('../scan_data/202110_all_scan_data.xlsx'),
                pd.read_excel('../scan_data/202111_all_scan_data.xlsx'),
                pd.read_excel('../scan_data/202112_all_scan_data.xlsx')])

preprocess_import_data(df)
df.head(3)
# Out:
#    age gender  height_cm  weight_kg adult_child department hospital_ward  \
# 0   72      M      170.0       83.0          成人        救急科            外来
# 1   72      M      170.0       83.0          成人        救急科            外来
# 2   85      M      171.0       58.9          成人      循環器内科            外来
#
#   scan_area scan_method                  scan_protocol      mA   CTDI
# 0   胸部〜骨盤CT          造影  5.7 P+CE Chest-Pelvis Routine  366.41  16.64
# 1   胸部〜骨盤CT          造影  5.7 P+CE Chest-Pelvis Routine  366.41  16.61
# 2   胸部〜骨盤CT          単純  5.7 P+CE Chest-Pelvis Routine  234.59  16.66

# %%
pd.merge(df, df_protocol, how='inner', on='scan_protocol')
# Out:
#       age gender  height_cm  weight_kg adult_child department hospital_ward  \
# 0      91      F      150.0      40.00          成人      脳神経外科            外来
# 1      91      F      150.0      40.00          成人      脳神経外科            外来
# 2      81      F      160.0      49.10          成人        救急科            外来
# 3      33      M      168.0      67.20          成人      脳神経外科            外来
# 4      49      M      176.0      73.00          成人      精神神経科            外来
# ...   ...    ...        ...        ...         ...        ...           ...
# 2748   81      M      160.0      62.85          成人        救急科            外来
# 2749   92      M      165.0      54.80          成人      脳神経外科            外来
# 2750   92      M      165.0      54.80          成人      脳神経外科            外来
# 2751   92      M      165.0      54.80          成人      脳神経外科            外来
# 2752   92      M      165.0      54.80          成人      脳神経外科            外来
#
#      scan_area  scan_method                                 scan_protocol  \
# 0          脳CT           単純                  1.7 Brain Head Routine TFI-H
# 1          脳CT           単純                  1.7 Brain Head Routine TFI-H
# 2          脳CT           単純                  1.7 Brain Head Routine TFI-H
# 3          脳CT           単純                  1.7 Brain Head Routine TFI-H
# 4          脳CT           単純                  1.7 Brain Head Routine TFI-H
# ...        ...          ...                                           ...
# 2748   胸椎・胸髄CT  Dual Energy                    7.7 GSIX  Th-Spine Routine
# 2749      脳CTA          CTA  1.14 Head-Neck CTA Helical SmartPrep Routine
# 2750      脳CTA          CTA  1.14 Head-Neck CTA Helical SmartPrep Routine
# 2751      脳CTA          CTA  1.14 Head-Neck CTA Helical SmartPrep Routine
# 2752      脳CTA          CTA  1.14 Head-Neck CTA Helical SmartPrep Routine
#
#       ...  Rows         SFOV   kV SmartmA NoiseIndex  MinmA  MaxmA CTDI_y  \
# 0     ...    64   Adult Head  100    true        4.0  150.0  515.0  55.19
# 1     ...    64   Adult Head  100    true        4.0  150.0  515.0  55.19
# 2     ...    64   Adult Head  100    true        4.0  150.0  515.0  55.19
# 3     ...    64   Adult Head  100    true        4.0  150.0  515.0  55.19
# 4     ...    64   Adult Head  100    true        4.0  150.0  515.0  55.19
# ...   ...   ...          ...  ...     ...        ...    ...    ...    ...
# 2748  ...    64       Medium  100     NaN        NaN    NaN    NaN  14.49
# 2749  ...    64   Adult Head  100   false       11.6  200.0  700.0   6.63
# 2750  ...    64   Adult Head  100   false        8.0  200.0  570.0  34.33
# 2751  ...    64   Adult Head  100   false       11.6  200.0  700.0   6.63
# 2752  ...    64   Adult Head  100   false        8.0  200.0  570.0  34.33
#
#       mA_y  pitch
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ...    ...    ...
# 2748   270     63
# 2749   NaN    NaN
# 2750   NaN    NaN
# 2751   NaN    NaN
# 2752   NaN    NaN
#
# [2753 rows x 26 columns]

# %%
len(df)
# Out:
# 2845

# %%
pd.merge(df, df_protocol, how='left', on='scan_protocol')
# Out:
#       age gender  height_cm  weight_kg adult_child department hospital_ward  \
# 0      72      M      170.0       83.0          成人        救急科            外来
# 1      72      M      170.0       83.0          成人        救急科            外来
# 2      85      M      171.0       58.9          成人      循環器内科            外来
# 3      91      F      150.0       40.0          成人      脳神経外科            外来
# 4      91      F      150.0       40.0          成人      脳神経外科            外来
# ...   ...    ...        ...        ...         ...        ...           ...
# 3765   74      M      172.0       66.6          成人      総合診療科            ５西
# 3766   74      M      172.0       66.6          成人      総合診療科            ５西
# 3767   67      M      167.0       64.0          成人      消化器内科            外来
# 3768   67      M      167.0       64.0          成人      消化器内科            外来
# 3769   67      M      167.0       64.0          成人      消化器内科            外来
#
#      scan_area scan_method                     scan_protocol  ...  Rows  \
# 0      胸部〜骨盤CT          造影     5.7 P+CE Chest-Pelvis Routine  ...   NaN
# 1      胸部〜骨盤CT          造影     5.7 P+CE Chest-Pelvis Routine  ...   NaN
# 2      胸部〜骨盤CT          単純     5.7 P+CE Chest-Pelvis Routine  ...   NaN
# 3          脳CT          単純      1.7 Brain Head Routine TFI-H  ...    64
# 4          脳CT          単純      1.7 Brain Head Routine TFI-H  ...    64
# ...        ...         ...                               ...  ...   ...
# 3765   胸部〜骨盤CT          造影     5.7 P+CE Chest-Pelvis Routine  ...   NaN
# 3766   胸部〜骨盤CT          造影     5.7 P+CE Chest-Pelvis Routine  ...   NaN
# 3767   胸部〜骨盤CT          造影  5.13 Aorta CTA Routine SmartPrep  ...   NaN
# 3768   胸部〜骨盤CT          造影  5.13 Aorta CTA Routine SmartPrep  ...   NaN
# 3769   胸部〜骨盤CT          造影  5.13 Aorta CTA Routine SmartPrep  ...   NaN
#
#              SFOV     kV SmartmA NoiseIndex  MinmA  MaxmA CTDI_y  mA_y  pitch
# 0             NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 1             NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 2             NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 3      Adult Head  100.0    true        4.0  150.0  515.0  55.19   NaN    NaN
# 4      Adult Head  100.0    true        4.0  150.0  515.0  55.19   NaN    NaN
# ...           ...    ...     ...        ...    ...    ...    ...   ...    ...
# 3765          NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 3766          NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 3767          NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 3768          NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
# 3769          NaN    NaN     NaN        NaN    NaN    NaN    NaN   NaN    NaN
#
# [3770 rows x 26 columns]
